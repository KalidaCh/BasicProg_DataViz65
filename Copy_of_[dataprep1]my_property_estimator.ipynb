# %% [markdown]
# <a href="https://colab.research.google.com/github/KalidaCh/BasicProg_DataViz65/blob/main/Copy_of_%5Bdataprep1%5Dmy_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
home = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
home
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor1 = home[home['ID ผู้ประเมิน']==1]
assessor1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
ret1_conf = plt.hist(assessor1['ความมั่นใจในการเมินราคาทรัพย์'])

# %%
ret1_score = plt.hist(assessor1['ให้คะแนนทรัพย์'])
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3], <a list of 4 Text major ticklabel objects>)

# %%
ret1_score
# Out:
# (array([43.,  0.,  0., 54.,  0.,  0.,  2.,  0.,  0.,  1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
assessor1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
assessor1.groupby(['ให้คะแนนทรัพย์']).count()
# Out:
#                                     ID ผู้ประเมิน  post id  property_type  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                               1        1              1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี             54       54             54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน              43       43             43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                2        2              2
#
#                                     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                                               1           1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                             54          54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                              43          43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                                2           2
#
#                                     ประเมินราคาซื้อ-ขาย  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                                     1
# ...

# %%
assessor1[assessor1['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี'].count()
# Out:
# ID ผู้ประเมิน                     54
# post id                           54
# property_type                     54
# ความมั่นใจในการเมินราคาทรัพย์     54
# ราคาทรัพย์                        54
# ประเมินราคาซื้อ-ขาย               54
# ปัจจัยในการประเมินราคาซื้อ-ขาย    54
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    54
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
assessor1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ## นักประเมินคนที่ 2

# %%
assessor2 = home[home['ID ผู้ประเมิน']==2]
print(f'ประเมินทั้งหมด {len(assessor2)}')
# Out:
# ประเมินทั้งหมด 90

# %%
assessor2.describe()['ประเมินราคาซื้อ-ขาย']
# Out:
# count    8.900000e+01
# mean     4.153258e+06
# std      2.386901e+06
# min      9.900000e+05
# 25%      2.600000e+06
# 50%      3.900000e+06
# 75%      4.900000e+06
# max      1.700000e+07
# Name: ประเมินราคาซื้อ-ขาย, dtype: float64

# %%
assessor2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
assessor2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ## เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย
#
# ## ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ
#
# ### hint เริ่มต้นมาเราอยากได้ตารางรูปแบบนี้ก่อน
# ![Screen Shot 2565-12-14 at 10.17.23.png](data:image/png;base64,...)

# %%
assessor2['ประเมินโดย1'] = assessor2['post id'].map(assessor1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
assessor2
# Out:
# <ipython-input-19-2dfcadf982ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor2['ประเมินโดย1'] = assessor2['post id'].map(assessor1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
assessor2[['post id','ราคาทรัพย์']]
# Out:
#                                    post id  ราคาทรัพย์
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0
# ..                                     ...         ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0
#
# [90 rows x 2 columns]

# %%
assessor2.rename(columns={'ราคาทรัพย์':'ราคาตั้งขาย'},inplace=True);
assessor2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# ...

# %%
assessor2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
assessor2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# ...

# %%
assessor = assessor2[['post id','ราคาตั้งขาย','ประเมินโดย1','ประเมินโดย2']]
assessor
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25    2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33    2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495    5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564    4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566    2750000.0    2500000.0
# ..                                     ...          ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495    5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496    7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20    2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31    4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570    1375000.0    1200000.0
#
#      ประเมินโดย2
# 1      2700000.0
# 3      2400000.0
# 5      9000000.0
# 7      3700000.0
# 9      2500000.0
# ..           ...
# ...

# %%
assessor.isnull().any()
# Out:
# post id        False
# ราคาตั้งขาย    False
# ประเมินโดย1    False
# ประเมินโดย2     True
# dtype: bool

# %%
assessorall = assessor.dropna(subset=['ประเมินโดย2'])
assessorall
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25    2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33    2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495    5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564    4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566    2750000.0    2500000.0
# ..                                     ...          ...          ...
# 185  https://nayoo.co/khonkaen/posts/19495    5500000.0    4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496    7911000.0    5200000.0
# 187     https://nayoo.co/khonkaen/posts/20    2000000.0    3600000.0
# 188     https://nayoo.co/khonkaen/posts/31    4000000.0    4000000.0
# 189    https://nayoo.co/khonkaen/posts/570    1375000.0    1200000.0
#
#      ประเมินโดย2
# 1      2700000.0
# 3      2400000.0
# 5      9000000.0
# 7      3700000.0
# 9      2500000.0
# ..           ...
# ...

# %%
assessorall.isnull().any()
# Out:
# post id        False
# ราคาตั้งขาย    False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %%
#from sklearn.metrics import mean_absolute_error
#Y_actual = [1,2,3,4,5]
#Y_Predicted = [1,2.5,3,4.1,4.9]
#mape = mean_absolute_error(Y_actual, Y_Predicted)*100
#print(mape)
#https://www.askpython.com/python/examples/mape-mean-absolute-percentage-error

# %%
Y_actual = assessorall[['ราคาตั้งขาย']]
Y_Predicted1 = assessorall[['ประเมินโดย1']]
Y_Predicted2 = assessorall[['ประเมินโดย2']]

# %% [markdown]
# ###บ้าน

# %%
from sklearn.metrics import mean_absolute_percentage_error
mapehome1 = mean_absolute_percentage_error(Y_actual, Y_Predicted1)
mapehome2 = mean_absolute_percentage_error(Y_actual, Y_Predicted2)
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {mapehome1*100:.2f}%\nนักประเมิน คนที่ 2 = {mapehome2*100:.2f}%')
one2two = mean_absolute_percentage_error(assessorall['ราคาตั้งขาย'],assessorall['ประเมินโดย2'])
two2one = mean_absolute_percentage_error(assessorall['ประเมินโดย2'],assessorall['ราคาตั้งขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(assessorall)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 12.32%
# นักประเมิน คนที่ 2 = 10.42%
# ความผิดพลาดระหว่างนักประเมินทั้ง 9.47%
# จำนวนทรัพย์ทั้งหมด 89 ทรัพย์

# %% [markdown]
# ###ที่ดิน

# %%
land = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_land1 = land[land['ID ผู้ประเมิน']==1] #ผู้ประเมินคนที่ 1
assessor_land1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 6                1   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 9                1   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 12               1   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 201              1  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 203              1  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_land1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02   10.000000
# mean             1.0  1.644375e+07         9.069000e+06    2.500000
# std              0.0  4.202164e+07         2.322360e+07    0.527046
# min              1.0  6.500000e+05         5.000000e+05    2.000000
# 25%              1.0  1.900000e+06         1.675000e+06    2.000000
# 50%              1.0  3.999500e+06         3.175000e+06    2.500000
# 75%              1.0  1.207500e+07         1.000000e+07    3.000000
# max              1.0  2.860000e+08         2.220000e+08    3.000000
#
#        Unnamed: 11  Unnamed: 12
# count          0.0          1.0
# mean           NaN        100.0
# std            NaN          NaN
# min            NaN        100.0
# 25%            NaN        100.0
# 50%            NaN        100.0
# 75%            NaN        100.0
# max            NaN        100.0

# %%
assessor_land2 = land[land['ID ผู้ประเมิน']==2] #ผู้ประเมินคนที่ 2
assessor_land2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# 204              2  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_land2['ประเมินโดย1'] = assessor_land2['post id'].map(assessor_land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
assessor_land2
# Out:
# <ipython-input-34-39e121fe0094>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_land2['ประเมินโดย1'] = assessor_land2['post id'].map(assessor_land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# ...

# %%
assessor_land2.rename(columns={'ราคาทรัพย์':'ราคาตั้งขาย'},inplace=True);
assessor_land2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# ...

# %%
assessor_land2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
assessor_land2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7                2   https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10               2   https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13               2   https://nayoo.co/khonkaen/posts/1866        ที่ดิน
# ..             ...                                    ...           ...
# 200              2  https://nayoo.co/khonkaen/posts/14539        ที่ดิน
# 202              2  https://nayoo.co/khonkaen/posts/16072        ที่ดิน
# ...

# %%
assessor_land = assessor_land2[['post id','ราคาตั้งขาย','ประเมินโดย1','ประเมินโดย2']]
assessor_land
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033      2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711     14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732     65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866      3000000    2200000.0
# ..                                     ...          ...          ...
# 200  https://nayoo.co/khonkaen/posts/14539      5000000    4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072       750000     500000.0
# 204  https://nayoo.co/khonkaen/posts/17093      2650000    2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112      1300000    1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145      3000000    2500000.0
#
#      ประเมินโดย2
# 1      2000000.0
# 4     12000000.0
# 7     70000000.0
# 10    60000000.0
# 13     2500000.0
# ..           ...
# ...

# %% [markdown]
# ####เขียน function ตรวจสอบค่าที่เติม 0 ผิด

# %%
def check_v(a,b):
    value1 = a/b
    value2 = b/a
    return max(a/b,b/a)

# %%
# check_v(100,1000)

# %% [markdown]
# ####สร้าง column ใหม่ ลงในตาราง home โดย ค่าใน column คือค่า จาก function check(ราคาตั้งขาย,ราคาประเมิน1)

# %%
assessor_land['check1']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_land
# Out:
# <ipython-input-40-cc9cee5e42d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_land['check1']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033      2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711     14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732     65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866      3000000    2200000.0
# ..                                     ...          ...          ...
# ...

# %%
assessor_land.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 194  https://nayoo.co/khonkaen/posts/13702     90000000    4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955      2600000   32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203    160000000   14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349    245000000   24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# ..                                     ...          ...          ...
# 182   https://nayoo.co/khonkaen/posts/9598      3900000    4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447       980000    1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663      1485000    1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762       650000     650000.0
# 130   https://nayoo.co/khonkaen/posts/1599      2500000    2500000.0
#
#      ประเมินโดย2     check1
# 194   75000000.0  20.000000
# 112    2000000.0  12.307692
# 58    11000000.0  11.428571
# ...

# %%
assessor_land['check2']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_land
# Out:
# <ipython-input-42-63806e64d332>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_land['check2']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033      2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711     14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732     65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866      3000000    2200000.0
# ..                                     ...          ...          ...
# ...

# %%
assessor_land.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 194  https://nayoo.co/khonkaen/posts/13702     90000000    4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955      2600000   32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203    160000000   14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349    245000000   24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# ..                                     ...          ...          ...
# 182   https://nayoo.co/khonkaen/posts/9598      3900000    4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447       980000    1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663      1485000    1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762       650000     650000.0
# 130   https://nayoo.co/khonkaen/posts/1599      2500000    2500000.0
#
#      ประเมินโดย2     check1     check2
# 194   75000000.0  20.000000  20.000000
# 112    2000000.0  12.307692  12.307692
# ...

# %%
#check1 = list()
#for row in assessor_land.iterrows():
   # check1.append(check_v(row[1]['ราคาตั้งขาย'],row[1]['ประเมินโดย1']))

# %%
 #check1

# %%
#assessor_land['check1_2']=check1
#assessor_land

# %%
assessor_land.isnull().any()
# Out:
# post id        False
# ราคาตั้งขาย    False
# ประเมินโดย1    False
# ประเมินโดย2    False
# check1         False
# check2         False
# dtype: bool

# %%
l_actual = assessor_land[['ราคาตั้งขาย']]
l_Predicted1 = assessor_land[['ประเมินโดย1']]
l_Predicted2 = assessor_land[['ประเมินโดย2']]

# %%
temp = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
idl1 = temp[temp['ID ผู้ประเมิน']==1]
idl1 = idl1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl2 = temp[temp['ID ผู้ประเมิน']==2]
idl2 = idl2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
from sklearn.metrics import mean_absolute_percentage_error
idl1MAPE = mean_absolute_percentage_error(idl1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl1['ราคาทรัพย์']))
idl2MAPE = mean_absolute_percentage_error(idl2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {idl1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idl2MAPE*100:.2f}%')
idl2['ประเมิน2'] = idl2['post id'].map(idl1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_l = idl2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twol = mean_absolute_percentage_error(id2_l['ประเมินราคาซื้อ-ขาย'],id2_l['ประเมิน2'])
two2onel = mean_absolute_percentage_error(id2_l['ประเมิน2'],id2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twol)+(two2onel))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_l)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %% [markdown]
# ###คอนโด

# %%
condo = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
condo
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# ...

# %%
assessor_condo1 = condo[condo['ID ผู้ประเมิน']==1] #ผู้ประเมินคนที่ 1
assessor_condo1
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# ...

# %%
assessor_condo1.rename(columns={'ราคาทรัพย์':'ราคาตั้งขาย'},inplace=True);
assessor_condo1
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาตั้งขาย  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0    3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# ...

# %%
assessor_condo1.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย1'},inplace=True);
assessor_condo1
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาตั้งขาย  ประเมินโดย1 ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0    3500000.0    3500000.0   60,000-130,000 บาท/ตารางเมตร
# 1    1930000.0    2200000.0    50,000-90,000 บาท/ตารางเมตร
# ...

# %%
assessor_condo = assessor_condo1[['post id','ราคาตั้งขาย','ประเมินโดย1']]
assessor_condo
# Out:
#    post id  ราคาตั้งขาย  ประเมินโดย1
# 0     32.0    3500000.0    3500000.0
# 1     36.0    1930000.0    2200000.0
# 2    603.0    2438000.0    2800000.0
# 3   1395.0    1600000.0    2300000.0
# 4   1443.0    1860000.0    1800000.0
# 5   1609.0    1490000.0    1500000.0
# 6   1640.0    1280000.0    1600000.0
# 7   1641.0    4290000.0    2700000.0
# 8   1650.0    1700000.0    1550000.0
# 9   1840.0    3790000.0    2800000.0

# %%
assessor_condo.isnull().any()
# Out:
# post id        False
# ราคาตั้งขาย    False
# ประเมินโดย1    False
# dtype: bool

# %%
c_actual = assessor_condo[['ราคาตั้งขาย']]
c_Predicted1 = assessor_condo[['ประเมินโดย1']]

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape_condo1 = mean_absolute_percentage_error(c_actual, c_Predicted1)
print(mape_condo1)
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nคอนโด\nนักประเมิน คนที่ 1 = {mape_condo1*100:.2f}%')
# Out:
# 0.17349265946250259
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# คอนโด
# นักประเมิน คนที่ 1 = 17.35%

# %% [markdown]
# ###ทาวน์โฮม

# %% [markdown]
# townhome

# %%
townhome = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
townhome
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_townhome1 = townhome[townhome['ID ผู้ประเมิน']==1] #ผู้ประเมินคนที่ 1
assessor_townhome1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 6                1    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 8                1    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 125              1  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 126              1  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 127              1  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 128              1  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 129              1  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_townhome2 = townhome[townhome['ID ผู้ประเมิน']==2] #ผู้ประเมินคนที่ 2
assessor_townhome2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_townhome2['ประเมินโดย1'] = assessor_townhome2['post id'].map(assessor_townhome1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
assessor_townhome2
# Out:
# <ipython-input-61-04a9eaa40758>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_townhome2['ประเมินโดย1'] = assessor_townhome2['post id'].map(assessor_townhome1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# ...

# %%
assessor_townhome2.rename(columns={'ราคาทรัพย์':'ราคาตั้งขาย'},inplace=True);
assessor_townhome2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# ...

# %%
assessor_townhome2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
assessor_townhome2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5                2    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7                2    https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9                2    https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# ...

# %%
assessor_townhome = assessor_townhome2[['post id','ราคาตั้งขาย','ประเมินโดย1','ประเมินโดย2']]
assessor_townhome
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1      https://nayoo.co/khonkaen/posts/548    1045000.0     700000.0
# 3      https://nayoo.co/khonkaen/posts/549     935000.0     700000.0
# 5      https://nayoo.co/khonkaen/posts/579    3520000.0    3500000.0
# 7      https://nayoo.co/khonkaen/posts/580    3850000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/582     990000.0    1000000.0
# ..                                     ...          ...          ...
# 235  https://nayoo.co/khonkaen/posts/18547    1430000.0    1000000.0
# 236  https://nayoo.co/khonkaen/posts/18551    1980000.0    1500000.0
# 237  https://nayoo.co/khonkaen/posts/19434    2000000.0    1600000.0
# 238  https://nayoo.co/khonkaen/posts/19501    1790000.0    1600000.0
# 239  https://nayoo.co/khonkaen/posts/20367    1590000.0    1700000.0
#
#      ประเมินโดย2
# 1      1500000.0
# 3      1500000.0
# 5      4000000.0
# 7      3200000.0
# 9       800000.0
# ..           ...
# ...

# %%
assessor_townhome.isnull().any()
# Out:
# post id        False
# ราคาตั้งขาย    False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %%
th_actual = assessor_townhome[['ราคาตั้งขาย']]
th_Predicted1 = assessor_townhome[['ประเมินโดย1']]
th_Predicted2 = assessor_townhome[['ประเมินโดย2']]

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape_townhome1 = mean_absolute_percentage_error(th_actual, th_Predicted1)
mape_townhome2 = mean_absolute_percentage_error(th_actual, th_Predicted2)
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {mape_townhome1*100:.2f}%\nนักประเมิน คนที่ 2 = {mape_townhome2*100:.2f}%')
one2two_th = mean_absolute_percentage_error(assessor_townhome['ราคาตั้งขาย'],assessor_townhome['ประเมินโดย2'])
two2one_th = mean_absolute_percentage_error(assessor_townhome['ประเมินโดย2'],assessor_townhome['ราคาตั้งขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two_th)+(two2one_th))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(assessor_townhome)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 11.37%
# นักประเมิน คนที่ 2 = 8.77%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.76%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %% [markdown]
# ###อาคารพาณิชย์

# %% [markdown]
# commercial building

# %%
cb = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
cb
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
assessor_cb1 = cb[cb['ID ผู้ประเมิน']==1] #ผู้ประเมินคนที่ 1
assessor_cb1
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 12              1   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 14              1  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 16              1  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 18              1  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_cb2 = cb[cb['ID ผู้ประเมิน']==2] #ผู้ประเมินคนที่ 2
assessor_cb2
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# 15              2  https://nayoo.co/khonkaen/posts/497  อาคารพาณิชย์/สำนักงาน
# 17              2  https://nayoo.co/khonkaen/posts/498  อาคารพาณิชย์/สำนักงาน
# 19              2  https://nayoo.co/khonkaen/posts/499  อาคารพาณิชย์/สำนักงาน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
assessor_cb2['ประเมินโดย1'] = assessor_cb2['post id'].map(assessor_cb1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
assessor_cb2
# Out:
# <ipython-input-71-7e7203f2de42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_cb2['ประเมินโดย1'] = assessor_cb2['post id'].map(assessor_cb1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# ...

# %%
assessor_cb2.rename(columns={'ราคาทรัพย์':'ราคาตั้งขาย'},inplace=True);
assessor_cb2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# ...

# %%
assessor_cb2.rename(columns={'ประเมินราคาซื้อ-ขาย':'ประเมินโดย2'},inplace=True);
assessor_cb2
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     ID ผู้ประเมิน                              post id          property_type  \
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 11              2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# 13              2   https://nayoo.co/khonkaen/posts/35  อาคารพาณิชย์/สำนักงาน
# ...

# %% [markdown]
# ###ตารางนี่

# %%
assessor_cb1 = assessor_cb2[['post id','ประเมินโดย1','ประเมินโดย2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
assessor_cb1
# Out:
#                                 post id  ประเมินโดย1  ประเมินโดย2  \
# 1     https://nayoo.co/khonkaen/posts/6    6000000.0    8000000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 5    https://nayoo.co/khonkaen/posts/21   13500000.0   20000000.0
# 7    https://nayoo.co/khonkaen/posts/22    4000000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24    2200000.0    3000000.0
# 11   https://nayoo.co/khonkaen/posts/30    3600000.0    4000000.0
# 13   https://nayoo.co/khonkaen/posts/35    2500000.0    2100000.0
# 15  https://nayoo.co/khonkaen/posts/497    3800000.0    5000000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    8000000.0
# 19  https://nayoo.co/khonkaen/posts/499    8000000.0   10000000.0
#
#                         ให้คะแนนทรัพย์ ความมั่นใจในการเมินราคาทรัพย์
# 1     4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                        มั่นใจ
# 3   2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                        มั่นใจ
# ...

# %%
assessor_cb = assessor_cb2[['post id','ราคาตั้งขาย','ประเมินโดย1','ประเมินโดย2','ให้คะแนนทรัพย์','ความมั่นใจในการเมินราคาทรัพย์']]
assessor_cb
# Out:
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# 15  https://nayoo.co/khonkaen/posts/497    5000000.0    3800000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    7000000.0
# 19  https://nayoo.co/khonkaen/posts/499    9000000.0    8000000.0
#
#     ประเมินโดย2                      ให้คะแนนทรัพย์  \
# 1     8000000.0    4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน
# 3    12000000.0  2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 5    20000000.0   3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน
# ...

# %%
assessor_cb.isnull().any()
# Out:
# post id        False
# ราคาตั้งขาย    False
# ประเมินโดย1    False
# ประเมินโดย2    False
# dtype: bool

# %%
cb_actual = assessor_cb[['ราคาตั้งขาย']]
cb_Predicted1 = assessor_cb[['ประเมินโดย1']]
cb_Predicted2 = assessor_cb[['ประเมินโดย2']]

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape_cb1 = mean_absolute_percentage_error(cb_actual, cb_Predicted1)
mape_cb2 = mean_absolute_percentage_error(cb_actual, cb_Predicted2)
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {mape_cb1*100:.2f}%\nนักประเมิน คนที่ 2 = {mape_cb2*100:.2f}%')
one2two_cb = mean_absolute_percentage_error(assessor_cb['ราคาตั้งขาย'],assessor_cb['ประเมินโดย2'])
two2one_cb = mean_absolute_percentage_error(assessor_cb['ประเมินโดย2'],assessor_cb['ราคาตั้งขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two_cb)+(two2one_cb))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(assessor_cb)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 17.64%
# นักประเมิน คนที่ 2 = 11.73%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.08%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# ##HW2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %% [markdown]
# ###checkบ้าน

# %%
assessorall['check1']=assessorall.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessorall
# Out:
# <ipython-input-78-754ad523bc1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessorall['check1']=assessorall.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25    2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33    2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495    5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564    4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566    2750000.0    2500000.0
# ..                                     ...          ...          ...
# ...

# %%
assessorall.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 187     https://nayoo.co/khonkaen/posts/20    2000000.0    3600000.0
# 75       https://nayoo.co/khonkaen/posts/1     390000.0     600000.0
# 177  https://nayoo.co/khonkaen/posts/19450    2100000.0    3200000.0
# 186  https://nayoo.co/khonkaen/posts/19496    7911000.0    5200000.0
# 101   https://nayoo.co/khonkaen/posts/6010    2860000.0    4200000.0
# ..                                     ...          ...          ...
# 167   https://nayoo.co/khonkaen/posts/9141    3500000.0    3500000.0
# 51    https://nayoo.co/khonkaen/posts/1149    4000000.0    4000000.0
# 63    https://nayoo.co/khonkaen/posts/2033    1200000.0    1200000.0
# 188     https://nayoo.co/khonkaen/posts/31    4000000.0    4000000.0
# 87    https://nayoo.co/khonkaen/posts/3905    1200000.0    1200000.0
#
#      ประเมินโดย2    check1
# 187    2500000.0  1.800000
# 75     1300000.0  1.538462
# 177    2200000.0  1.523810
# ...

# %%
assessorall['check2']=assessorall.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessorall
# Out:
# <ipython-input-80-0399adecbf17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessorall['check2']=assessorall.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1       https://nayoo.co/khonkaen/posts/25    2700000.0    2500000.0
# 3       https://nayoo.co/khonkaen/posts/33    2600000.0    2200000.0
# 5      https://nayoo.co/khonkaen/posts/495    5900000.0    5000000.0
# 7      https://nayoo.co/khonkaen/posts/564    4400000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/566    2750000.0    2500000.0
# ..                                     ...          ...          ...
# ...

# %%
assessorall.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 187     https://nayoo.co/khonkaen/posts/20    2000000.0    3600000.0
# 75       https://nayoo.co/khonkaen/posts/1     390000.0     600000.0
# 177  https://nayoo.co/khonkaen/posts/19450    2100000.0    3200000.0
# 186  https://nayoo.co/khonkaen/posts/19496    7911000.0    5200000.0
# 101   https://nayoo.co/khonkaen/posts/6010    2860000.0    4200000.0
# ..                                     ...          ...          ...
# 167   https://nayoo.co/khonkaen/posts/9141    3500000.0    3500000.0
# 51    https://nayoo.co/khonkaen/posts/1149    4000000.0    4000000.0
# 63    https://nayoo.co/khonkaen/posts/2033    1200000.0    1200000.0
# 188     https://nayoo.co/khonkaen/posts/31    4000000.0    4000000.0
# 87    https://nayoo.co/khonkaen/posts/3905    1200000.0    1200000.0
#
#      ประเมินโดย2    check1    check2
# 187    2500000.0  1.800000  1.800000
# 75     1300000.0  1.538462  1.538462
# ...

# %% [markdown]
# ###checkที่ดิน

# %%
assessor_land['check1']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_land
# Out:
# <ipython-input-82-cc9cee5e42d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_land['check1']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033      2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711     14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732     65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866      3000000    2200000.0
# ..                                     ...          ...          ...
# ...

# %%
assessor_land.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 194  https://nayoo.co/khonkaen/posts/13702     90000000    4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955      2600000   32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203    160000000   14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349    245000000   24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# ..                                     ...          ...          ...
# 182   https://nayoo.co/khonkaen/posts/9598      3900000    4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447       980000    1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663      1485000    1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762       650000     650000.0
# 130   https://nayoo.co/khonkaen/posts/1599      2500000    2500000.0
#
#      ประเมินโดย2     check1     check2
# 194   75000000.0  20.000000  20.000000
# 112    2000000.0  12.307692  12.307692
# ...

# %%
assessor_land['check2']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_land
# Out:
# <ipython-input-84-63806e64d332>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_land['check2']=assessor_land.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/1033      2800000    1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711     14900000    8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732     65000000   35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866      3000000    2200000.0
# ..                                     ...          ...          ...
# ...

# %%
assessor_land.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 194  https://nayoo.co/khonkaen/posts/13702     90000000    4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955      2600000   32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203    160000000   14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349    245000000   24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726     90000000   18000000.0
# ..                                     ...          ...          ...
# 182   https://nayoo.co/khonkaen/posts/9598      3900000    4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447       980000    1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663      1485000    1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762       650000     650000.0
# 130   https://nayoo.co/khonkaen/posts/1599      2500000    2500000.0
#
#      ประเมินโดย2     check1     check2
# 194   75000000.0  20.000000  20.000000
# 112    2000000.0  12.307692  12.307692
# ...

# %%
temp = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/copy of คำตอบนักประเมิน .xlsx',sheet_name='ที่ดิน')
idl1 = temp[temp['ID ผู้ประเมิน']==1]
idl1 = idl1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl2 = temp[temp['ID ผู้ประเมิน']==2]
idl2 = idl2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
from sklearn.metrics import mean_absolute_percentage_error
idl1MAPE = mean_absolute_percentage_error(idl1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl1['ราคาทรัพย์']))
idl2MAPE = mean_absolute_percentage_error(idl2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nที่ดิน\nนักประเมิน คนที่ 1 = {idl1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idl2MAPE*100:.2f}%')
idl2['ประเมิน2'] = idl2['post id'].map(idl1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_l = idl2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twol = mean_absolute_percentage_error(id2_l['ประเมินราคาซื้อ-ขาย'],id2_l['ประเมิน2'])
two2onel = mean_absolute_percentage_error(id2_l['ประเมิน2'],id2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twol)+(two2onel))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_l)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# ที่ดิน
# นักประเมิน คนที่ 1 = 53.94%
# นักประเมิน คนที่ 2 = 25.89%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.21%
# จำนวนทรัพย์ทั้งหมด 40 ทรัพย์

# %% [markdown]
# ###checkทาวน์โฮม

# %%
assessor_townhome['check1']=assessor_townhome.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_townhome
# Out:
# <ipython-input-87-64fd5e333ad4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_townhome['check1']=assessor_townhome.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1      https://nayoo.co/khonkaen/posts/548    1045000.0     700000.0
# 3      https://nayoo.co/khonkaen/posts/549     935000.0     700000.0
# 5      https://nayoo.co/khonkaen/posts/579    3520000.0    3500000.0
# 7      https://nayoo.co/khonkaen/posts/580    3850000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/582     990000.0    1000000.0
# ..                                     ...          ...          ...
# ...

# %%
assessor_townhome.sort_values(by=['check1'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 176   https://nayoo.co/khonkaen/posts/3528    2190000.0     350000.0
# 180   https://nayoo.co/khonkaen/posts/6095    2420000.0    1500000.0
# 132    https://nayoo.co/khonkaen/posts/619    1430000.0     950000.0
# 1      https://nayoo.co/khonkaen/posts/548    1045000.0     700000.0
# 174   https://nayoo.co/khonkaen/posts/3478    2190000.0    1500000.0
# ..                                     ...          ...          ...
# 228  https://nayoo.co/khonkaen/posts/17923    1990000.0    2000000.0
# 167   https://nayoo.co/khonkaen/posts/2829    2490000.0    2500000.0
# 220  https://nayoo.co/khonkaen/posts/17545    2800000.0    2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411    3200000.0    3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503    1500000.0    1500000.0
#
#      ประเมินโดย2    check1
# 176     400000.0  6.257143
# 180    1500000.0  1.613333
# 132    1000000.0  1.505263
# ...

# %%
assessor_townhome['check2']=assessor_townhome.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_townhome
# Out:
# <ipython-input-89-28efccac672f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_townhome['check2']=assessor_townhome.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1      https://nayoo.co/khonkaen/posts/548    1045000.0     700000.0
# 3      https://nayoo.co/khonkaen/posts/549     935000.0     700000.0
# 5      https://nayoo.co/khonkaen/posts/579    3520000.0    3500000.0
# 7      https://nayoo.co/khonkaen/posts/580    3850000.0    3500000.0
# 9      https://nayoo.co/khonkaen/posts/582     990000.0    1000000.0
# ..                                     ...          ...          ...
# ...

# %%
assessor_townhome.sort_values(by=['check2'],ascending=False)
# Out:
#                                    post id  ราคาตั้งขาย  ประเมินโดย1  \
# 176   https://nayoo.co/khonkaen/posts/3528    2190000.0     350000.0
# 180   https://nayoo.co/khonkaen/posts/6095    2420000.0    1500000.0
# 132    https://nayoo.co/khonkaen/posts/619    1430000.0     950000.0
# 1      https://nayoo.co/khonkaen/posts/548    1045000.0     700000.0
# 174   https://nayoo.co/khonkaen/posts/3478    2190000.0    1500000.0
# ..                                     ...          ...          ...
# 228  https://nayoo.co/khonkaen/posts/17923    1990000.0    2000000.0
# 167   https://nayoo.co/khonkaen/posts/2829    2490000.0    2500000.0
# 220  https://nayoo.co/khonkaen/posts/17545    2800000.0    2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411    3200000.0    3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503    1500000.0    1500000.0
#
#      ประเมินโดย2    check1    check2
# 176     400000.0  6.257143  6.257143
# 180    1500000.0  1.613333  1.613333
# ...

# %% [markdown]
# ###checkอาคารพาณิชย์

# %%
assessor_cb['check1']=assessor_cb.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_cb
# Out:
# <ipython-input-91-d158225103e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_cb['check1']=assessor_cb.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# ...

# %%
assessor_cb.sort_values(by=['check1'],ascending=False)
# Out:
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 15  https://nayoo.co/khonkaen/posts/497    5000000.0    3800000.0
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 19  https://nayoo.co/khonkaen/posts/499    9000000.0    8000000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    7000000.0
#
#     ประเมินโดย2    check1
# 9     3000000.0  1.772727
# 5    20000000.0  1.666667
# 11    4000000.0  1.333333
# 15    5000000.0  1.315789
# 1     8000000.0  1.166667
# 7     4000000.0  1.142857
# 19   10000000.0  1.125000
# ...

# %%
assessor_cb['check2']=assessor_cb.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
assessor_cb
# Out:
# <ipython-input-93-fa9dec39af4b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   assessor_cb['check2']=assessor_cb.apply(lambda x:check_v(x.ราคาตั้งขาย,x.ประเมินโดย1),axis=1);
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# ...

# %%
assessor_cb.sort_values(by=['check2'],ascending=False)
# Out:
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 15  https://nayoo.co/khonkaen/posts/497    5000000.0    3800000.0
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 19  https://nayoo.co/khonkaen/posts/499    9000000.0    8000000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    7000000.0
#
#     ประเมินโดย2    check1    check2
# 9     3000000.0  1.772727  1.772727
# 5    20000000.0  1.666667  1.666667
# 11    4000000.0  1.333333  1.333333
# 15    5000000.0  1.315789  1.315789
# 1     8000000.0  1.166667  1.166667
# ...

# %% [markdown]
# ###Load ตารางจาก google sheet

# %%
import gspread as gs
import pandas as pd

# %%
link = 'https://docs.google.com/spreadsheets/d/1USArlRg7uQwwOv1HIUk_bOYbPBKJggZsq7IIdywBszI/export?format=xlsx'
land = pd.read_excel(link,sheet_name= 'land')
land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #HW3 visualize แสดงความสัมพันธ์ ราคา(ตั้งขายและประเมิน)-ความมั่นใจ-ให้คะแนนทรัพย์

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[12,6]

# %%
assessor_cb
# Out:
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# 15  https://nayoo.co/khonkaen/posts/497    5000000.0    3800000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    7000000.0
# 19  https://nayoo.co/khonkaen/posts/499    9000000.0    8000000.0
#
#     ประเมินโดย2    check1    check2
# 1     8000000.0  1.166667  1.166667
# 3    12000000.0  1.000000  1.000000
# 5    20000000.0  1.666667  1.666667
# 7     4000000.0  1.142857  1.142857
# 9     3000000.0  1.772727  1.772727
# ...

# %%
assessor_cb.sort_values(by=['check2'],ascending=False)
# Out:
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  \
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0
# 15  https://nayoo.co/khonkaen/posts/497    5000000.0    3800000.0
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0
# 19  https://nayoo.co/khonkaen/posts/499    9000000.0    8000000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    7000000.0
#
#     ประเมินโดย2    check1    check2
# 9     3000000.0  1.772727  1.772727
# 5    20000000.0  1.666667  1.666667
# 11    4000000.0  1.333333  1.333333
# 15    5000000.0  1.315789  1.315789
# 1     8000000.0  1.166667  1.166667
# ...

# %%
cb1 = assessor_cb[['post id','ราคาตั้งขาย','ประเมินโดย1','ประเมินโดย2']].sort_values('ราคาตั้งขาย', ascending=False)
cb1
# Out:
#                                 post id  ราคาตั้งขาย  ประเมินโดย1  ประเมินโดย2
# 5    https://nayoo.co/khonkaen/posts/21   22500000.0   13500000.0   20000000.0
# 3    https://nayoo.co/khonkaen/posts/17   12000000.0   12000000.0   12000000.0
# 19  https://nayoo.co/khonkaen/posts/499    9000000.0    8000000.0   10000000.0
# 1     https://nayoo.co/khonkaen/posts/6    7000000.0    6000000.0    8000000.0
# 17  https://nayoo.co/khonkaen/posts/498    7000000.0    7000000.0    8000000.0
# 15  https://nayoo.co/khonkaen/posts/497    5000000.0    3800000.0    5000000.0
# 11   https://nayoo.co/khonkaen/posts/30    4800000.0    3600000.0    4000000.0
# 9    https://nayoo.co/khonkaen/posts/24    3900000.0    2200000.0    3000000.0
# 7    https://nayoo.co/khonkaen/posts/22    3500000.0    4000000.0    4000000.0
# 13   https://nayoo.co/khonkaen/posts/35    2400000.0    2500000.0    2100000.0

# %%
assessor_cb.plot(kind='bar', x='post id',width=0.7,colormap='tab10')
plt.xlabel('post id')
plt.ylabel('ราคาประเมิน')
plt.title('xxxxxx');

# %%
assessor_cb1.plot(kind='bar', x='ให้คะแนนทรัพย์',width=0.7,colormap='tab10')
plt.xlabel('ให้คะแนนทรัพย์')
plt.ylabel('IDนักประเมิน')
plt.title('xxxxxx');

# %%
assessor_cb1.plot(kind='bar', x='ความมั่นใจในการเมินราคาทรัพย์',width=0.7,colormap='tab10')
plt.xlabel('ความมั่นใจในการเมินราคาทรัพย์')
plt.ylabel('IDนักประเมิน')
plt.title('xxxxxx');
